# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast

# %%
df = pd.read_csv('data/coursera_course_details.csv')
df
# Out:
#                                                  Title  \
# 0    Microsoft Business Analyst Professional Certif...
# 1          Data Engineering Foundations Specialization
# 2                              Psychological First Aid
# 3    Tableau Business Intelligence Analyst Professi...
# 4                      Think like a CFO Specialization
# ..                                                 ...
# 355      IBM Business Analyst Professional Certificate
# 356     Adobe Content Creator Professional Certificate
# 357  Google IT Automation with Python Professional ...
# 358  Generative AI Engineering with LLMs Specializa...
# 359  Generative AI for Program Managers Specialization
#
#                       Partner                    Subject  \
# 0                   Microsoft          Business Strategy
# 1                         IBM            Data Management
# 2    Johns Hopkins University                 Psychology
# 3    Tableau Learning Partner              Data Analysis
# 4        IESE Business School                    Finance
# ..                        ...                        ...
# 355                       IBM        Business Essentials
# 356                     Adobe                  Marketing
# 357                    Google     Support and Operations
# 358                       IBM           Machine Learning
# 359                       IBM  Leadership and Management
#
#                                            Description  Rating  \
# 0    Launch your career as a business analyst. Buil...     4.6
# 1    Build the Foundation for a Data Engineering Ca...     4.7
# 2                  Instructor: George Everly, Jr., PhD     4.8
# 3    Launch your career in Data Analytics. Build in...     4.7
# 4                     Instructors: Marc Badia\n+2 more     4.8
# ..                                                 ...     ...
# 355  Get job-ready as a Business Analyst. Build the...     4.8
# 356  Launch your career as a content creator.. Buil...     4.7
# 357  Learn in-demand skills like Python, Git, and I...     4.8
# 358  Advance your ML career with Gen AI and LLMs. M...     4.5
# 359  Supercharge your program management with GenAI...     4.8
#
#                   Level             Duration  \
# 0        Beginner level             3 months
# 1        Beginner level             2 months
# 2                   NaN  6 hours to complete
# 3        Beginner level             8 months
# 4        Beginner level              1 month
# ..                  ...                  ...
# 355      Beginner level             3 months
# 356      Beginner level             4 months
# 357      Advanced level             6 months
# 358  Intermediate level             3 months
# 359  Intermediate level              1 month
#
#                                                 Skills  \
# 0    ['Business Process Modeling', 'Pivot Tables An...
# 1    ['Database Design', 'Database Management Syste...
# 2    ['Trauma Care', 'Crisis Intervention', 'Triage...
# 3    ['Spatial Data Analysis', 'Data Visualization ...
# 4    ['Balance Sheet', 'Working Capital', 'Capital ...
# ..                                                 ...
# 355  ['Stakeholder Engagement', 'Business Analytics...
# 356  ['Storytelling', 'Content Marketing', 'Social ...
# 357  ['Unit Testing', 'Programming Principles', 'Gi...
# 358  ['Text Mining', 'Large Language Modeling', 'Ap...
# 359  ['Project Management', 'Large Language Modelin...
#
#                                                    URL
# 0    https://www.coursera.org/professional-certific...
# 1    https://www.coursera.org/specializations/data-...
# 2    https://www.coursera.org/learn/psychological-f...
# 3    https://www.coursera.org/professional-certific...
# 4    https://www.coursera.org/specializations/think...
# ..                                                 ...
# 355  https://www.coursera.org/professional-certific...
# 356  https://www.coursera.org/professional-certific...
# 357  https://www.coursera.org/professional-certific...
# 358  https://www.coursera.org/specializations/gener...
# 359  https://www.coursera.org/specializations/gener...
#
# [360 rows x 9 columns]

# %%
duplicate_rows = df[df.duplicated()]
print("Number of duplicate rows:", duplicate_rows.shape[0])
display(duplicate_rows)
# Out:
# Number of duplicate rows: 0
# Empty DataFrame
# Columns: [Title, Partner, Subject, Description, Rating, Level, Duration, Skills, URL]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        360 non-null    object
#  1   Partner      360 non-null    object
#  2   Subject      360 non-null    object
#  3   Description  360 non-null    object
#  4   Rating       356 non-null    float64
#  5   Level        342 non-null    object
#  6   Duration     360 non-null    object
#  7   Skills       360 non-null    object
#  8   URL          360 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 25.4+ KB

# %% [markdown]
# ## Handle missing values

# %% [markdown]
# 📍 from dataframe info, we can see that there are missing/null data in rating and level column

# %% [markdown]
# ### 1️⃣ Handle rating column

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Rating'].dropna(), kde=True, bins=20, color='pink')
plt.title('Distribution of Course Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
median_rating = df['Rating'].median()
df['Rating'] = df['Rating'].fillna(median_rating)

# %% [markdown]
# ### 2️⃣ Handle level column

# %%
print(df['Level'].unique())
# Out:
# ['Beginner level' nan 'Intermediate level' 'Advanced level']

# %%
mode_val = df['Level'].mode()[0]
df['Level'] = df['Level'].fillna(mode_val)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        360 non-null    object
#  1   Partner      360 non-null    object
#  2   Subject      360 non-null    object
#  3   Description  360 non-null    object
#  4   Rating       360 non-null    float64
#  5   Level        360 non-null    object
#  6   Duration     360 non-null    object
#  7   Skills       360 non-null    object
#  8   URL          360 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 25.4+ KB

# %% [markdown]
# ## Replace unusual value

# %% [markdown]
# While skimming through the dataset, I noticed that some entries in the description column contain unusual values, specifically, courses without a proper description instead display the instructor's name

# %%
print(df['Description'].unique())
# Out:
# ['Launch your career as a business analyst. Build job-ready skills for an in-demand career in business analysis in as little as 3 months. No prior experience required to get started.'
#  'Build the Foundation for a Data Engineering Career. Develop hands-on experience with Python, SQL, and Relational Databases and master the fundamentals of the Data Engineering ecosystem.'
#  'Instructor: George Everly, Jr., PhD'
#  'Launch your career in Data Analytics. Build in-demand skills and gain credentials to go from beginner to job-ready in 8 months or less. No degree or prior experience required.'
#  'Instructors: Marc Badia\n+2 more'
#  'Master Fundamental and Advanced React Concepts. Learn all about React, from basic concepts to advanced practices'
#  'Learn Excel Skills for Business. Master Excel to add a highly valuable asset to your employability portfolio.'
#  'Steer Your Business to Success. Generate value and demonstrate global impact in four courses.'
#  'Copilot Mastery for Leaders. Master Microsoft 365 Copilot and redefine leadership productivity'
#  'Advance your career in IT as a Scrum Master. Develop the in-demand skills and hands-on experience to get job-ready in 3 months'
#  'Prepare for a career as a data scientist. Build job-ready skills – and must-have AI skills – for an in-demand career. Earn a credential from IBM. No prior experience required.'
#  '#BreakIntoAI with Machine Learning Specialization. Master fundamental AI concepts and develop practical machine learning skills in the beginner-friendly, 3-course program by AI visionary Andrew Ng'
#  'This course is part of Google IT Automation with Python Professional Certificate'
#  'Make Compelling Design. Learn and apply the principles of graphic design towards a comprehensive branding project.'
#  'Master Skills of an AI Agent Software Developer. Learn to design, build, and refine intelligent software agents using Python, generative AI, and agentic architectures for real-world applications.'
#  'Get job-ready as a product owner in 3-4 months. Build the skills employers look for on a resume and prepare for the PSPO I certification exam. No prior experience required!'
#  'Map Your World With GIS. Explore the tools, concepts, and terminology of spatial analysis and modeling'
#  'Become a better manager of people. Develop strategies and skills for hiring, managing performance, and rewarding employees.'
#  'Develop job-ready gen AI skills employers need. Build highly sought-after gen AI engineering skills and practical experience in just 6 months. No prior experience required.'
#  'This course is part of Google Data Analytics Professional Certificate'
#  'This course is part of Google UX Design Professional Certificate'
#  'This course is part of Google AI Essentials Specialization'
#  'Instructor: Andrew Ng'
#  'Launch your career in Cloud Architecture. Design, develop, and manage cloud solutions to drive business objectives.'
#  'Human Anatomy and Physiology for Allied Health. Learn the anatomical structures and terminology relevant to the human body through this interactive, engaging online content.'
#  'This course is part of Google Project Management: Professional Certificate'
#  'This course is part of multiple programs.\nLearn more'
#  'Become a Successful Entry-Level Payroll Specialist. Gain the knowledge and develop job-ready skills for an exciting career in the diverse field of payroll. No degree or experience required.'
#  "Launch your career in Human Resources. In this program, you’ll learn in-demand skills for a career as an Human Resource Associate. No degree or prior experience needed. Coursera's 2024 Learners First Award Winner."
#  'Launch your career in bookkeeping. Gain the professional skills you need to succeed in the bookkeeping field. No degree or prior experience required.'
#  'Launch your career as a Social Media Marketer. Build job-ready skills – and must-have AI skills – for an in-demand career. Earn a credential from Meta 5 months or less. No degree or prior experience required.'
#  'Get ahead w/ Data Analysis & Visualization skills. Enhance your career by learning to analyze data using Excel spreadsheets, and create stunning visualizations and interactive dashboards with Cognos.'
#  'Advance Your Knowledge in Financial Engineering. Build the fundamentals and technical skills in financial engineering'
#  'Advance your career as a Cloud ML Engineer'
#  'Prepare for a career as a Data Engineer. Build job-ready skills – and must-have AI skills – for an in-demand career. Earn a credential from IBM. No prior experience required.'
#  'Instructors: Erica Corbellini\n+1 more' 'Instructor: Vishal Gupta'
#  'Get job-ready as a program manager in 2 months. Build in-demand skills and prepare for the PMI-PgMP certification exam. No experience required.'
#  'This course is part of Google Digital Marketing & E-commerce Professional Certificate'
#  'Start a career as a Cloud Technology Consultant. In this program, you’ll learn in-demand skills to advise clients on the use of cloud technology to meet business objectives. No degree or experience required.'
#  'Leverage AI in your software development workflow. Learn practical prompt engineering and pair programming techniques with LLMs to write, test, and improve your code.'
#  'Learn in-demand skills like statistical analysis, Python, regression models, and machine learning in less than 6 months.'
#  'This course is part of Google IT Support Professional Certificate'
#  'Instructor: Paul Bloom'
#  'TESOL Certificate Part II: Teach English Now!. Apply principles of language teaching for reading, writing, listening & speaking.'
#  'Launch your career as an iOS developer. Build job-ready skills for an in-demand career and earn a credential from Meta. No degree or prior experience required to get started.'
#  "Management Consultant's Careers Skills Tools. Work like a management consultant: smarter, and faster"
#  'Advance your career as an SRE & DevOps Engineer'
#  'Launch Your Career as a Business Analyst. Build in-demand skills and earn a credential to go from beginner to job-ready in less than 4 months.'
#  'Prepare for a career as an IT support specialist. Build job-ready skills and prep for the CompTIA ITF+ certification exam. No prior experience needed.'
#  'Improve Your Career With Six Sigma Knowledge. Learn proven principles and tools to improve quality assurance in your organization'
#  'Kickstart your career in artificial intelligence. Build job-ready skills in AI technologies, generative AI models, and programming and learn to build AI-powered chatbots and apps in just 6 months'
#  'Harness Generative AI for Engaging K-12 Teaching. Learn to integrate generative AI into your teaching to create engaging lessons, foster student creativity, and enhance problem-solving in the classroom.'
#  'Launch your career in Cloud Cybersecurity. Build job-ready skills – and must-have AI skills – for an in-demand career. Earn a credential from Google Cloud. No prior experience required.'
#  'Prepare for a career as a data analyst. Build job-ready skills – and must-have AI skills – for an in-demand career. Earn a credential from IBM. No prior experience required.'
#  'Launch your Full-Stack JavaScript Developer career. Build the skills and hands-on experience to get job-ready in under four months. No prior experience required.'
#  'Boost your project management career with gen AI. Learn in-demand skills and gain generative AI expertise to advance your project management career in less than a month.'
#  'Advance your career in cloud architecture.'
#  'Instructor: Dr. Paul L. Gareau'
#  'Understand Generative AI Security & Best Practices. Learners will understand generative AI-specific security threats and vulnerabilities while mastering strategies to enhance organizational preparedness through advanced tabletop exercises and proactive cybersecurity planning.'
#  'AI Marketing Strategies for Growth and Success. Harness AI tools & data strategies to launch and optimize today’s modern marketing campaigns.'
#  'Learn about Global Procurement and Sourcing. Reviews the key aspects of global procurement and sourcing, and the importance of procurement to the firm, its stakeholders, and suppliers.'
#  'Kickstart Your Career as a Cloud Native Developer. Learn the foundational front-end and back-end skills for developing and deploying applications on Cloud.'
#  'This course is part of Google Prompting Essentials Specialization'
#  'Instructors: John Rofrano\n+1 more'
#  "Master ChatGPT's Free AI to Excel at Work & Life. Leverage ChatGPT's free AI to excel at planning, project management, writing, data analytics, marketing, social media, machine learning, and more for work and life."
#  'Build the Foundation for your Data Science career. Develop hands-on experience with Jupyter, Python, SQL. Perform Statistical Analysis on real data sets.'
#  'Launch your career as a Python Developer. Learn in-demand Python skills and become a job-ready developer in less than 4 months. No degree or experience required.'
#  'Get job-ready for your first data-related role. Build skills and hands-on experience employers are looking for & power up your resume in less than 3 months. No degree or prior experience required.'
#  'Improve Your English Communication Skills. Write and speak more professionally in English to increase your business success.'
#  'Learn the principles of effective data engineering. Build your skills in the high-demand field of data engineering and learn how you can deliver real business value by applying a core set of principles and strategies for developing data systems.'
#  'Boost your software development career with Gen AI. Build in-demand hands-on Generative AI skills for your elevating your software engineering game in 1 month or less'
#  'Manage the Design & Development of ML Products. Understand how machine learning works and when and how it can be applied to solve problems. Learn to apply the data science process and best practices to lead machine learning projects, and how to develop human-centered AI products which ensure privacy and ethical standards.'
#  'Master AI Research for Strategic Leadership. Master generative AI research to transform strategic decision-making and competitive intelligence'
#  'Critically Analyze Research and Results Using R. Learn to recognize sloppy science, perform solid research and do appropriate data analysis.'
#  'Instructor: Dr. Kristin Sainani'
#  'Advance your career as a Cloud Networking Engineer'
#  'Launch Your Career in Salesforce. Learn the foundational skills in Salesforce needed to start a new career.'
#  'Instructors: Matthew Lungren\n+7 more'
#  'Instructors: R. Polk Wagner\n+3 more'
#  'Reimagine Workflows with Google Cloud Gen AI'
#  'Instructor: Laurie Santos'
#  'Unlock your UI/UX career with job-ready skills. Build skills & hands-on experience employers are looking for, including Figma and Miro, in 4 months.'
#  'Mastering Generative AI for Strategic Advantage. Empower your leadership suite with the transformative potential of Generative AI'
#  'Advance your career in data engineering'
#  'Launch Your Career in Games. Learn to create worlds that captivate and inspire while building in-demand skills with the foundations for game design with Unreal Engine. No prior experience required'
#  'Instructors: Alex Aklson\n+3 more'
#  'Break into NLP. Master cutting-edge NLP techniques through four hands-on courses! Updated with TensorFlow labs in December 2023.'
#  'Develop key power skills to boost your work life. Master powerful people and soft skills for achieving professional success.'
#  'Innovate in your classroom and school. Master techniques for using ChatGPT to enhance rather than harm education'
#  'Master the Concepts of Reinforcement Learning. Implement a complete RL solution and understand how to apply AI tools to solve real-world problems.'
#  'Get on the fast track to a career in Data Analytics. In this certificate program, you’ll learn in-demand skills, and get AI training from Google experts. Learn at your own pace, no degree or experience required.'
#  'Instructor: Google'
#  'Get Ahead with Key Business Technologies. Gain Foundational Understanding of Key Technologies Driving Modern Businesses'
#  'This course is part of Google Cybersecurity Professional Certificate'
#  'Unlock your potential in SAP Consulting. Build the core skills SAP Partners and customers are searching for across the world, and kick-start an exciting SAP career.'
#  'Instructor: Eunjung Grace Oh' 'Instructor: Dr. Wayne Whiteman, PE'
#  'Instructor: Rajkumar Venkatesan'
#  'Launch your career as a Junior Software Developer. Build job-ready skills for an in-demand career in software development in as little as 4 months. No prior experience or degree required to get started.'
#  'This course is part of Machine Learning Specialization'
#  'Learn about ESG Factors When Investing. Analyze the importance of ESG investing. Identify how the ESG approach should be an essential piece of your strategy based on various factors impacting and driving value.'
#  'Launch your career as an AI Product Manager. Build in-demand product management and generative AI skills to get job ready in 3 months or less.'
#  'Become an Excellent Public Speaker. Master techniques for designing and delivering clear and compelling presentations.'
#  'Launch your career as a back-end developer. Build job-ready skills for an in-demand career and earn a credential from Meta. No degree or prior experience required to get started.'
#  'Building AI Applications on AWS Cloud. Learn AI fundamentals and AWS services to develop practical applications to enhance productivity'
#  'Strategic Insights for Leaders on Agentic AI. Gain the knowledge to lead AI innovation in your organization by understanding Agentic AI and AI Agents.'
#  'Advance your career in health care management. Develop business skills and understand the American health care system to improve cost and quality.'
#  'Master Algorithmic Programming Techniques. Advance your Software Engineering or Data Science Career by Learning Algorithms through Programming and Puzzle Solving. Ace coding interviews by implementing each algorithmic challenge in this Specialization. Apply the newly-learned algorithmic techniques to real-life problems, such as analyzing a huge social network or sequencing a genome of a deadly pathogen.'
#  'Make Data-Driven Business Decisions. Achieve fluency in business data strategies in four discipline-specific courses.'
#  'Construction Project Management and Planning. Develop and understand the foundations of project planning and scheduling techniques'
#  'Prepare for a career in machine learning. Gain the in-demand skills and hands-on experience to get job-ready in less than 3 months.'
#  'Launch your career in Cloud Security. This self-paced Specialization gives a broad study of security controls, best practices, and techniques on Google Cloud.'
#  'Develop a Robust Foundation in Data Analytics. Build a job-ready data analytics skillset using industry-standard tools, including generative AI, to extract insights, make decisions, and solve real-world business problems.'
#  'Instructors: Tianjing Li, MD, MHS, PHD\n+1 more'
#  'Positive Psychology: Well-being for life. Master strategies and tools that enable individuals and organizations to thrive'
#  'Become a Prompt Engineering Expert. Master prompt engineering patterns, techniques, and approaches to effectively leverage Generative AI'
#  'Get job-ready to launch your cybersecurity career. Build the information security skills and hands-on experience employers look for in less than 4 months. No prior experience required.'
#  'Discover your JavaScript developer potential. Solidify your cloud application developer skills with essential JavaScript technologies and NoSQL databases'
#  'Boost Your Productivity with AI Tools. New to AI? Learn from Google experts how AI can help you speed up daily tasks and spark new ideas.'
#  'Become a Machine Learning expert. Master the fundamentals of deep learning and break into AI. Recently updated with cutting-edge techniques!'
#  'Advance your cloud career in database engineering'
#  'Generative AI Mastery: Automate with ChatGPT. Learn to perform complex tasks effortlessly using the power of generative AI'
#  'Learn to Program and Analyze Data with Python. Develop programs to gather, clean, analyze, and visualize data.'
#  'Become fluent in the rules of the new economy. Learn how to use intellectual property law to protect and maximize the value of your innovations'
#  'Become a Fluent Python Programmer. Learn the fundamentals and become an independent programmer.'
#  'Learn cosmetic science from Olay scientists. Build a foundational understanding about the industry processes of creating safe and effective cosmetic formulas for skincare, haircare, hygiene cosmetics, color cosmetics, cleansing, and fragrances.'
#  'Explore the Scope of Dentistry and Oral Health. After completing this specialization, the learner will be able to recognize the scope of dental therapy and identify the relationship between oral and systemic health.'
#  'Fast-track your deep learning engineering career. Build the deep learning expertise employers are looking for in just 3 months'
#  'Instructors: Alex G.\n+3 more'
#  'Prepare for a Career in AI & ML Engineering. Build, deploy, and innovate with advanced techniques and real-world projects. Intermediate programming knowledge of Python required.'
#  'Pursue your passion and improve your productivity. Learn how to use the best-in-class suite of apps that help you stay connected and get things done.'
#  'Enterprise AI Automation With Java AI Agents. Learn to build powerful AI agents and AI agent architectures in Java that work with nearly any API.'
#  'Build real-world AI with RAG and agentic AI. Use AI tools to streamline automation, drive innovation & take your career further, faster.'
#  'Master Mental Health Theories and Development. Gain a thorough understanding of mental health through professional standards, theoretical frameworks, and comprehensive insights into developmental stages, difficulties, and disorders.'
#  'Learn to execute successful M&A strategies. Learners will be able to gain a wholistic understanding of how successful M&A deals are structured and executed to create value for the organization'
#  'Elevate your Product Manager career with Gen AI. Build in-demand hands-on generative AI skills to boost your Product Manager career in under 2 months. No experience needed to get started'
#  'Learn and Master Full-Stack Web Development. Master both front-end and back-end skills to build web apps end-to-end'
#  'Get on the fast track to a career in digital marketing. In this certificate program, you’ll learn in-demand skills, and get AI training from Google experts. Learn at your own pace, no degree or experience required.'
#  'Launch your career as a cybersecurity professional. Build job-ready skills and prep for the CompTIA Security+ exam with this program.'
#  'Get on the fast track to a career in UX design. In this certificate program, you’ll learn in-demand skills, and get AI training from Google experts. Learn at your own pace, no degree or experience required.'
#  'Learn the Fundamentals of AI and Machine Learning. Develop a deployment strategy for incorporating AI, ML, and Big Data into your organization that will take advantage of cutting-edge technologies'
#  'Launch your career in Business Intelligence. Gain the in-demand skills and hands-on experience to get job-ready in less than 4 months. No prior experience required.'
#  'Launch your generative AI Data Engineering career. Get job-ready as a data engineer with knowledge of generative AI! No prior experience necessary'
#  'This course is part of Introduction to Generative AI Learning Path Specialization'
#  'Master CNA Skills with Healthcare Knowledge. Equip students with essential CNA skills, professional practices, and knowledge of anatomy.'
#  'Future-proof your Java career opportunities. Master GenAI & create AI Java apps in 2 months. No prior AI experience required.'
#  'Instructor: Leonard E. White, Ph.D.'
#  'Become an SEO Expert. Master search engine optimization tools and strategies'
#  'Launch your career as a Power BI analyst. Build job-ready skills for an in-demand career in as little as 3 months. No prior experience required to get started. This program can also prepare you for the Microsoft PL-300 Certification exam.'
#  'Make Smarter Business Decisions With Data Analysis. Understand data, apply data analytics tools and create effective business intelligence presentations'
#  'Get job-ready for your first role in BI. Build the in-demand skills you need to get started in business intelligence (BI) in just 2 months. No degree or prior experience required.'
#  'Instructors: Alicia Álvarez\n+2 more'
#  'Launch your Product Manager career with Microsoft. Learn in-demand market research skills and become a job-ready Product Manager in less than 3 months. No degree or experience required.'
#  'Build job-ready front-end skills employers need. Master the development skills to plan, build, deploy, and test web designs and application interfaces in just 4 months!'
#  'Unlock Potential of Gen AI for Customer Support. Learn how to leverage the capabilities and tools of generative AI to provide enhanced customer support and drive excellent customer experiences in just 3 weeks!'
#  'Instructor: Google Cloud Training'
#  'This course is part of Deep Learning Specialization'
#  'Get job-ready as an AI engineer. Build the AI engineering skills and practical experience you need to catch the eye of an employer in less than 4 months. Power up your resume!'
#  'Explore Art and Ideas of Our Time. Develop a deeper understanding of artists’ and designers’ processes, and gain confidence in looking at and talking about art.'
#  'ChatGPT-Powered Email Automation and Productivity. Master ChatGPT-driven workflows to automate email tasks, streamline communication, and organize important information effortlessly with Zapier.'
#  'Instructor: George Siedel'
#  'Power your Product Owner career with GenAI. Become proficient in GenAI tools in 3 weeks to optimize the product lifecycle and drive results.'
#  'Build Business and Financial Models. Use spreadsheet models to make data-driven financial decisions'
#  'Mathematics for Machine Learning. Learn about the prerequisite mathematics for applications in data science and machine learning'
#  'Launch your career in data analytics. Build job-ready skills – and must-have AI skills – for an in-demand career. Earn a credential from Meta in 5 months or less. No degree or prior experience required.'
#  'This course is part of Intuit Academy Bookkeeping Professional Certificate'
#  'Become a Power BI and Power Platform Expert. Boost Productivity, Automate Processes, and Gain Valuable Insights'
#  'Learn AI Agent Fundamentals from the Ground Up. Learn how to build resilient AI agents and develop Agentic AI skills in Python that will remain relevant despite the rapidly evolving AI landscape.'
#  'Instructor: Seung Hae Kang'
#  'Launch your career in marketing.. Build job-ready skills in digital marketing, content development, branding, and social media.'
#  'Turn Your Idea into a Funded Business. Develop, launch, fund and grow your own business'
#  'Instructors: Michael R Roberts\n+4 more'
#  'Data Engineering on Google Cloud. Launch your career in Data Engineering. Deliver business value with big data and machine learning.'
#  'Instructor: Erik Brynjolfsson'
#  'Kickstart a new IT and Cloud Career. Master hardware, operating systems, programming, database, networking, storage, cybersecurity, and Cloud computing essentials.'
#  'Instructor: NVIDIA Training' 'Instructors: Jennifer Carbrey\n+1 more'
#  'Leadership and Business Skill for Immediate Impact. Apply practical strategies to becoming an effective organizational leader.'
#  'Launch Your Career in Personal Fitness Training. Master the knowledge and skills required to support clients in making lasting lifestyle changes.'
#  "Educator's Prompt Engineering. Elevate teaching with tailored generative AI prompting skills"
#  'Build Essential Skills for the Workplace. Improve your employability and advance in today’s dynamic workforce.'
#  'Master Personal Automation with ChatGPT and Zapier. Learn how to harness ChatGPT, AI tools, GPTs, and Zapier to automate tasks, enhance productivity, and effectively solve real-world challenges across various domains.'
#  'Foundational Pharmacy Technician Career Training. Start your pharmacy career by learning the essentials of dosages, prescriptions, anatomy, and the soft skills essential to any healthcare career.'
#  'Instructors: Don Noxon\n+4 more'
#  'Be a next generation sequencing data scientist.. Master the tools and techniques at the forefront of the sequencing data revolution.'
#  'Drive to Value with Agile Methods. Master an adaptive approach to product development'
#  'Instructors: Matthew O. Jackson\n+2 more'
#  'Advance Your IT Career with Cybersecurity Skills. Gain Flexibility with Self-Paced Learning'
#  'Unlock the Potential of Generative AI in BI. Learn how you can use the capabilities and tools of generative AI to boost your career in business intelligence'
#  'Learn to create a culture of compliance. Master the strategies for building an effective compliance program to manage risk'
#  'ChatGPT-Powered Excel: Transform Data Into Insight. Master AI-driven Excel skills to automate tasks, uncover insights, and create impactful data visualizations.'
#  'This course is part of AI For Business Specialization'
#  'Prepare for a career as a systems analyst. Build in-demand skills & hands-on experience employers want. No prior experience or degree required'
#  'Instructors: Michael Lenox\n+5 more'
#  "Law's Generative AI Edge. Harness Generative AI to transform legal research and practice"
#  'Launch your career as a Cloud Support Associate. Build job-ready skills for an in-demand career in information technology in as little as 6 months. No prior experience required to get started.'
#  'Instructor: Robert Shiller'
#  'This course is part of AI in Healthcare Specialization'
#  'Instructor: Nader Tavassoli'
#  'Break into a new career as a Product Manager. No prior experience necessary to quickly get job ready as a certified product manager'
#  'Instructor: Joseph W. Cutrone, PhD'
#  'Launch your graphic design career.. Learn design fundamentals to build job-ready skills using Adobe Photoshop, Illustrator, and Express'
#  'Prepare for a career as a product manager. Gain the in-demand skills and hands-on experience to get job ready in less than 3 months. No prior experience required.'
#  'Learn to build AI apps with Tensorflow. Build, train, and optimize deep neural networks and dive deep into Computer Vision, Natural Language Processing, and Time Series Analysis, along with best practices and hands-on experience in one of the most in-demand deep learning frameworks.'
#  'Launch Your Career in Data Science. A ten-course introduction to data science, developed and taught by leading professors.'
#  'Launch your career in Cybersecurity. Acquire the knowledge you need to work in Cybersecurity'
#  'Get ahead with key business and technical skills. Understand how current technologies are changing industry and create strategy to transform your business'
#  'Instructors: Christopher Geczy\n+4 more'
#  'Improve Your Career With Advanced Six Sigma. Dive deeper into proven principles and tools to improve quality assurance in your organization'
#  'Launch your career as a cybersecurity analyst. Build job-ready skills – and must-have AI skills – for an in-demand career. Earn a credential from Microsoft. No prior experience required.'
#  'Understanding Procedures and Administration. Medical Office Procedures and Administration Fundamentals provides students with a comprehensive overview of key administrative functions in healthcare settings, including patient scheduling, medical billing, office management, and essential regulatory compliance – equipping them with the foundational skills needed to excel in medical office administration.'
#  'Learn To Think Like A Computer Scientist. Master the fundamentals of the design and analysis of algorithms.'
#  'Master Project Management with ChatGPT. Learn how to leverage ChatGPT and AI to streamline project planning, execution, and optimization, transforming how you manage and deliver successful projects.'
#  'Kickstart your Career in BI Engineering. Develop job-ready skills for an entry level role in Data Warehousing.'
#  'Launch your career as a Database Engineer. Build job-ready skills for an in-demand career and earn a credential from Meta. No degree or experience required to get started.'
#  'Advance your career to high demand field of DevOps. Build on your software development skills with the latest DevOps concepts, tools, and technologies to get job ready in less than 3 months.'
#  'Get job-ready as a mobile app developer. Build iOS and Android mobile app development skills and practical experience employers look for in just 6 months. No programming experience needed.'
#  'Launch your career in cloud computing. Build job-ready skills and gain credentials to go from beginner to job-ready in 4 months or less. No degree or prior experience required.'
#  'Generative AI for You. Build and train personalized assistants with Generative AI'
#  'Understanding Finance and Financial Markets. Learners will gain comprehensive knowledge and skills in financial markets, corporate finance, accounting, investment strategies, risk management, and ESG principles.'
#  'Instructors: Dr. Bonnie H. Ferri\n+1 more'
#  'Prepare for a career as a full stack developer. Build job-ready skills – and must-have AI skills – for an in-demand career. Earn a credential from IBM.'
#  'Instructor: Stefano Caselli'
#  'Fast-track your career with job-ready GenAI skills. Master GenAI-powered mobile app development and build the practical experience employers are looking for in just 3 months.'
#  'Instructors: Amirhossein Kiani\n+3 more' 'Instructor: Peggy Mason'
#  'Launch your career as a project manager. Build job-ready skills and prepare for the Project Management Professional (PMP) certification exam. No prior experience required.'
#  'Instructor: Barry Nalebuff'
#  'Prepare for a career in data analytics. Gain the in-demand skills and hands-on experience to get job-ready in less than 3 months. No prior experience required.'
#  "Get on the fast track to a career in cybersecurity. In this certificate program, you'll learn in-demand skills, and get AI training from Google experts. Learn at your own pace, no degree or experience required."
#  'Launch your Career in Full-Stack Development. Start your journey as a full-stack developer. Develop job-ready AI-powered skills and earn a certificate from Microsoft. No experience required.'
#  'Learn the basics of finance and accounting. Build a foundation of core business skills in finance and accounting'
#  'This course is part of Python for Everybody Specialization'
#  'Gain the Medical Billing and Coding Fundamentals. Prepare for a career in the Medical Billing industry by gaining an understanding of the language of insurance, revenue cycles, and more.'
#  'Launch your career in Cloud Data Analytics. Build in-demand skills and gain credentials to go from beginner to job-ready in 10 weeks or less. No degree or prior experience required.'
#  'Instructor: Maya Adam, MD'
#  'Leading Effectively. Learn proven management techniques in just four courses.'
#  'Launch your career as a front-end developer. Build job-ready skills for an in-demand career and earn a credential from Meta. No degree or prior experience required to get started.'
#  'Prepare for a career as a back-end developer. Gain the in-demand skills and hands-on experience to get job-ready in less than 6 months.'
#  'Launch your career as an IT project manager. Get job-ready and prep for the Certified Associate in Project Management (CAPM) certification exam.'
#  'Drive Customer Behavior Online. A six-course overview of the latest digital marketing skills, taught by industry experts.'
#  'Instructor: Guenther Walther'
#  'Unlock AI’s Potential with Effective Prompts. Learn from Google experts how to use AI effectively by writing clear and specific prompts.'
#  'Reinvent teaching with gen AI-powered innovation. Learn how to leverage gen AI tools to transform education and training and drive excellent learning experiences in just a few weeks!'
#  'Developer Best Practices on Google Cloud'
#  'Learn in-demand skills like data modeling, data visualization, and dashboarding and reporting in less than 2 months.'
#  'Launch your career as an IT support specialist. Build job-ready skills – and must-have AI skills – for an in-demand career. Earn a credential from Microsoft. No prior experience required.'
#  'Unlock Academic & Career Success with Data Science. Build the foundational knowledge and hands-on skills you need to forge new career opportunities, with no technical experience required.'
#  'Launch your career as a data architect. Learn in-demand skills like data engineering, database management, and data architecture in less than 5 months.'
#  'Learn machine learning with Google Cloud. Real-world experimentation with end-to-end ML'
#  'Learn machine learning through real use cases. Build the skills for a career in one of the most relevant fields of modern AI through hands-on projects and curriculum from IBM’s experts.'
#  'Build the foundation of your career in Software. Develop hands-on experience with Git, GitHub, Linux, and Python, and learn the fundamentals of Software Engineering.'
#  'Gain foundational literacy in cloud & digital transformation. Increase your cloud confidence so you can speak with colleagues in technical cloud roles and contribute to informed cloud-related business decisions.'
#  'Become a Generative AI Data Analyst. Learn how to use ChatGPT and generative AI tools to analyze data, automate workflows, and communicate insights with clarity and impact.'
#  'Boost Your Computer Programming Skills. With minimal previous exposure, learn two popular programming languages at an accelerated pace.'
#  'Use generative AI features in Google Workspace. Learn how to use generative AI with Gemini for Google Workspace to improve your productivity and efficiency'
#  'Launch your career in data science. Gain foundational data science skills to prepare for a career or further advanced learning in data science.'
#  'This course is part of Business Foundations Specialization'
#  'Unlock and leverage the potential of generative AI. Learn how you can use the capabilities of generative AI to enhance your work and daily life.'
#  'Launch your Career in Back-End Development. Start your journey as a back-end developer. Develop job-ready AI-powered skills and earn a certificate from Microsoft. No prior experience is required.'
#  'Start your career in the cloud.'
#  'Prepare for a career as a Java developer. Gain the in-demand skills and hands-on experience to get job-ready in 3 months. No prior experience required.'
#  'Instructors: Jeffery Atik\n+8 more'
#  'Implement a modern approach to product management. Master the fundamentals that create great teams and products'
#  'Develop Excel Skills from Microsoft. Develop your data analysis skills in Excel with AI-driven Copilot, hands-on projects, and expert guidance to accelerate your career.'
#  'Instructor: Workday Education'
#  'Build generative AI skills for data analytics. Enhance your career as a data analyst with knowledge of generative AI! No prior experience necessary.'
#  'Launch your Back-End JavaScript Developer career. Build the skills and hands-on experience to get job-ready in under four months. No degree or prior experience required.'
#  'Power up your business analysis career with GenAI. Build the game-changing GenAI skills businesses need in 3 weeks. No AI experience required.'
#  'Enhance your career in Cybersecurity with AI. Build in-demand generative AI skills and gain credentials for your cybersecurity career in 3 months or less. No degree or prior experience required.'
#  'AI-Driven Database Design For Professionals. Master SQL database design, query generation, and data visualization using AI.'
#  'Instructors: Dr Andrew Heys\n+5 more'
#  'Supply Chain Management. Master the Fundamentals: Logistics, Operations, Planning, Sourcing, and Strategy'
#  'Solve Real Business Problems. Build a foundation of core business skills in marketing, finance, accounting and operations.'
#  'Start here to become an AWS Solutions Architect. Gain the skills and knowledge to design architectural solutions on AWS and prepare for your AWS Certified Solutions Architect - Associate exam.'
#  'Boost Your Career with New Business Knowledge. Master Business Management Fundamentals'
#  'Understand nature like a biologist.. Embark on a journey from the classroom to museums and nature reserves to gain a broad overview and appreciation of three important fields of biology.'
#  'Launch your DevOps and Software Engineering Career. Master DevOps, Agile, Scrum, CI/CD and Cloud Native with hands-on job-ready skills.'
#  'The launchpad to a career in IT. This program is designed to take beginner learners to job readiness in about three-to-six months.'
#  'Get hands-on skills for a career in data science. Learn Python, analyze and visualize data. Apply your skills to data science and machine learning.'
#  'Master AI to Transform HR Operations. Master AI patterns to streamline hiring, development, and communications.'
#  'Advance Your IT Career with Cybersecurity Skills. Gain Flexibility with Self-Paced Learning.'
#  'Instructors: Chris Fregly\n+3 more'
#  'TESOL Certificate, Part 1: Teach English Now!. Learn theory and the practical strategies of English as a Second Language teaching.'
#  'Master Microsoft Office and Power Platform. Boost your productivity and become an Expert in Word, Excel, PowerPoint, and Power Platform'
#  'Learn essential skills in cancer biology, cancer metastasis, and prostate cancer, that will enable you to develop a deeper understanding of the impact of cancer on the human body.'
#  'Advance your career as a Cloud Security Engineer'
#  'Instructors: Roger D. Peng, PhD\n+2 more'
#  'Launch Your Career in Marketing Analytics. Build job-ready skills – and must-have AI skills – for an in-demand career. Earn a credential from Meta in 7 months or less. No degree or prior experience required.'
#  'Leap ahead in data science using generative AI. Build in-demand hands-on generative AI skills to supercharge your data science career in under 1 month'
#  'Unlock Potential of Gen AI in Digital Marketing. Learn how to leverage the capabilities & tools of genAI to create effective marketing content'
#  'Instructors: Brian McManus\n+1 more'
#  'GCP Principles for Ethical Clinical Trials'
#  'Enhance Your Skills in Risk Management. Understand the theory and practice of risk management and the expected results from a successful risk management process.'
#  'Instructor: Xi Yang'
#  'Get on the fast track to a career in project management. In this certificate program, you’ll learn in-demand skills, and get AI training from Google experts. Learn at your own pace, no degree or experience required.'
#  'Build smarter apps with RAG and GenAI Tools. Get hands-on building GenAI-powered apps using RAG, vector databases, & advanced retrieval tools.'
#  'Launch Your Career as an English Teacher. Master strategies to teach English as a second or foreign language.'
#  'Unlock your potential with AI. Build job-ready AI skills to enhance your career. Everyone welcome. No prior AI background required.'
#  'Become a cross-platform mobile app developer. Learn in-demand skills for developing reliable, scalable and user-friendly mobile apps for multiple operating systems, such as iOS and Android.'
#  'Build job-ready database skills. Gain practical experience in the high-demand fields of data management and data engineering, valued by employers with hands-on skills and experience employers look for.'
#  'Launch your career as an Android app developer. Build job-ready skills for an in-demand career and earn a credential from Meta. No degree or prior experience required to get started.'
#  'Master fundamental web development skills. Build frontend and backend skills in web development to start your journey as a web developer'
#  'This course is part of Mathematics for Machine Learning and Data Science Specialization'
#  'Unlock the Potential of Generative AI in HR. Learn how you can use the capabilities and tools of generative AI to enhance your career in human resources (HR)'
#  'Prepare for a career as an IT project manager. Build job-ready skills and prepare for the CAPM certification exam. No prior experience required.'
#  'Instructor: Dr Dan Plesch, SOAS University of London'
#  'Unlock your cybersecurity professional potential. Develop fluency in essential Cybersecurity skills and competencies and safeguard your digital assets.'
#  'Master the Toolkit of AI and Machine Learning. Mathematics for Machine Learning and Data Science is a beginner-friendly Specialization where you’ll learn the fundamental mathematics toolkit of machine learning: calculus, linear algebra, statistics, and probability.'
#  'Get job-ready as a Business Analyst. Build the essential skills, technical expertise, and hands-on experience with key business analysis tools'
#  'Launch your career as a content creator.. Build in-demand skills in visual design, social media , and multimedia storytelling.'
#  'Learn in-demand skills like Python, Git, and IT automation to advance your career'
#  'Advance your ML career with Gen AI and LLMs. Master the essentials of Gen AI engineering and large language models (LLMs) in just 3 months.'
#  'Supercharge your program management with GenAI. Master GenAI tools and techniques to enhance your program management capabilities and outcomes.']

# %% [markdown]
# For now, i'm gonna replace those values with the corresponding course title

# %%
for index, row in df.iterrows():
    if "Instructors:" in row['Description'] or "Instructor:" in row['Description']:
        df.loc[index, 'Description'] = row['Title']

# %%
print(df['Description'].unique())
# Out:
# ['Launch your career as a business analyst. Build job-ready skills for an in-demand career in business analysis in as little as 3 months. No prior experience required to get started.'
#  'Build the Foundation for a Data Engineering Career. Develop hands-on experience with Python, SQL, and Relational Databases and master the fundamentals of the Data Engineering ecosystem.'
#  'Psychological First Aid'
#  'Launch your career in Data Analytics. Build in-demand skills and gain credentials to go from beginner to job-ready in 8 months or less. No degree or prior experience required.'
#  'Think like a CFO Specialization'
#  'Master Fundamental and Advanced React Concepts. Learn all about React, from basic concepts to advanced practices'
#  'Learn Excel Skills for Business. Master Excel to add a highly valuable asset to your employability portfolio.'
#  'Steer Your Business to Success. Generate value and demonstrate global impact in four courses.'
#  'Copilot Mastery for Leaders. Master Microsoft 365 Copilot and redefine leadership productivity'
#  'Advance your career in IT as a Scrum Master. Develop the in-demand skills and hands-on experience to get job-ready in 3 months'
#  'Prepare for a career as a data scientist. Build job-ready skills – and must-have AI skills – for an in-demand career. Earn a credential from IBM. No prior experience required.'
#  '#BreakIntoAI with Machine Learning Specialization. Master fundamental AI concepts and develop practical machine learning skills in the beginner-friendly, 3-course program by AI visionary Andrew Ng'
#  'This course is part of Google IT Automation with Python Professional Certificate'
#  'Make Compelling Design. Learn and apply the principles of graphic design towards a comprehensive branding project.'
#  'Master Skills of an AI Agent Software Developer. Learn to design, build, and refine intelligent software agents using Python, generative AI, and agentic architectures for real-world applications.'
#  'Get job-ready as a product owner in 3-4 months. Build the skills employers look for on a resume and prepare for the PSPO I certification exam. No prior experience required!'
#  'Map Your World With GIS. Explore the tools, concepts, and terminology of spatial analysis and modeling'
#  'Become a better manager of people. Develop strategies and skills for hiring, managing performance, and rewarding employees.'
#  'Develop job-ready gen AI skills employers need. Build highly sought-after gen AI engineering skills and practical experience in just 6 months. No prior experience required.'
#  'This course is part of Google Data Analytics Professional Certificate'
#  'This course is part of Google UX Design Professional Certificate'
#  'This course is part of Google AI Essentials Specialization'
#  'AI Python for Beginners'
#  'Launch your career in Cloud Architecture. Design, develop, and manage cloud solutions to drive business objectives.'
#  'Human Anatomy and Physiology for Allied Health. Learn the anatomical structures and terminology relevant to the human body through this interactive, engaging online content.'
#  'This course is part of Google Project Management: Professional Certificate'
#  'This course is part of multiple programs.\nLearn more'
#  'Become a Successful Entry-Level Payroll Specialist. Gain the knowledge and develop job-ready skills for an exciting career in the diverse field of payroll. No degree or experience required.'
#  "Launch your career in Human Resources. In this program, you’ll learn in-demand skills for a career as an Human Resource Associate. No degree or prior experience needed. Coursera's 2024 Learners First Award Winner."
#  'Launch your career in bookkeeping. Gain the professional skills you need to succeed in the bookkeeping field. No degree or prior experience required.'
#  'Launch your career as a Social Media Marketer. Build job-ready skills – and must-have AI skills – for an in-demand career. Earn a credential from Meta 5 months or less. No degree or prior experience required.'
#  'Get ahead w/ Data Analysis & Visualization skills. Enhance your career by learning to analyze data using Excel spreadsheets, and create stunning visualizations and interactive dashboards with Cognos.'
#  'Advance Your Knowledge in Financial Engineering. Build the fundamentals and technical skills in financial engineering'
#  'Advance your career as a Cloud ML Engineer'
#  'Prepare for a career as a Data Engineer. Build job-ready skills – and must-have AI skills – for an in-demand career. Earn a credential from IBM. No prior experience required.'
#  'Management of Fashion and Luxury Companies' 'Leadership Skills'
#  'Get job-ready as a program manager in 2 months. Build in-demand skills and prepare for the PMI-PgMP certification exam. No experience required.'
#  'This course is part of Google Digital Marketing & E-commerce Professional Certificate'
#  'Start a career as a Cloud Technology Consultant. In this program, you’ll learn in-demand skills to advise clients on the use of cloud technology to meet business objectives. No degree or experience required.'
#  'Leverage AI in your software development workflow. Learn practical prompt engineering and pair programming techniques with LLMs to write, test, and improve your code.'
#  'Learn in-demand skills like statistical analysis, Python, regression models, and machine learning in less than 6 months.'
#  'This course is part of Google IT Support Professional Certificate'
#  'Introduction to Psychology'
#  'TESOL Certificate Part II: Teach English Now!. Apply principles of language teaching for reading, writing, listening & speaking.'
#  'Launch your career as an iOS developer. Build job-ready skills for an in-demand career and earn a credential from Meta. No degree or prior experience required to get started.'
#  "Management Consultant's Careers Skills Tools. Work like a management consultant: smarter, and faster"
#  'Advance your career as an SRE & DevOps Engineer'
#  'Launch Your Career as a Business Analyst. Build in-demand skills and earn a credential to go from beginner to job-ready in less than 4 months.'
#  'Prepare for a career as an IT support specialist. Build job-ready skills and prep for the CompTIA ITF+ certification exam. No prior experience needed.'
#  'Improve Your Career With Six Sigma Knowledge. Learn proven principles and tools to improve quality assurance in your organization'
#  'Kickstart your career in artificial intelligence. Build job-ready skills in AI technologies, generative AI models, and programming and learn to build AI-powered chatbots and apps in just 6 months'
#  'Harness Generative AI for Engaging K-12 Teaching. Learn to integrate generative AI into your teaching to create engaging lessons, foster student creativity, and enhance problem-solving in the classroom.'
#  'AI For Everyone'
#  'Launch your career in Cloud Cybersecurity. Build job-ready skills – and must-have AI skills – for an in-demand career. Earn a credential from Google Cloud. No prior experience required.'
#  'Prepare for a career as a data analyst. Build job-ready skills – and must-have AI skills – for an in-demand career. Earn a credential from IBM. No prior experience required.'
#  'Launch your Full-Stack JavaScript Developer career. Build the skills and hands-on experience to get job-ready in under four months. No prior experience required.'
#  'Boost your project management career with gen AI. Learn in-demand skills and gain generative AI expertise to advance your project management career in less than a month.'
#  'Advance your career in cloud architecture.' 'Indigenous Canada'
#  'Understand Generative AI Security & Best Practices. Learners will understand generative AI-specific security threats and vulnerabilities while mastering strategies to enhance organizational preparedness through advanced tabletop exercises and proactive cybersecurity planning.'
#  'AI Marketing Strategies for Growth and Success. Harness AI tools & data strategies to launch and optimize today’s modern marketing campaigns.'
#  'Learn about Global Procurement and Sourcing. Reviews the key aspects of global procurement and sourcing, and the importance of procurement to the firm, its stakeholders, and suppliers.'
#  'Kickstart Your Career as a Cloud Native Developer. Learn the foundational front-end and back-end skills for developing and deploying applications on Cloud.'
#  'This course is part of Google Prompting Essentials Specialization'
#  'DevOps, Cloud, and Agile Foundations Specialization'
#  "Master ChatGPT's Free AI to Excel at Work & Life. Leverage ChatGPT's free AI to excel at planning, project management, writing, data analytics, marketing, social media, machine learning, and more for work and life."
#  'Build the Foundation for your Data Science career. Develop hands-on experience with Jupyter, Python, SQL. Perform Statistical Analysis on real data sets.'
#  'Launch your career as a Python Developer. Learn in-demand Python skills and become a job-ready developer in less than 4 months. No degree or experience required.'
#  'Get job-ready for your first data-related role. Build skills and hands-on experience employers are looking for & power up your resume in less than 3 months. No degree or prior experience required.'
#  'Improve Your English Communication Skills. Write and speak more professionally in English to increase your business success.'
#  'Learn the principles of effective data engineering. Build your skills in the high-demand field of data engineering and learn how you can deliver real business value by applying a core set of principles and strategies for developing data systems.'
#  'Boost your software development career with Gen AI. Build in-demand hands-on Generative AI skills for your elevating your software engineering game in 1 month or less'
#  'Manage the Design & Development of ML Products. Understand how machine learning works and when and how it can be applied to solve problems. Learn to apply the data science process and best practices to lead machine learning projects, and how to develop human-centered AI products which ensure privacy and ethical standards.'
#  'Master AI Research for Strategic Leadership. Master generative AI research to transform strategic decision-making and competitive intelligence'
#  'Critically Analyze Research and Results Using R. Learn to recognize sloppy science, perform solid research and do appropriate data analysis.'
#  'Writing in the Sciences'
#  'Advance your career as a Cloud Networking Engineer'
#  'Launch Your Career in Salesforce. Learn the foundational skills in Salesforce needed to start a new career.'
#  'AI in Healthcare Specialization' 'Healthcare Law Specialization'
#  'Reimagine Workflows with Google Cloud Gen AI'
#  'The Science of Well-Being'
#  'Unlock your UI/UX career with job-ready skills. Build skills & hands-on experience employers are looking for, including Figma and Miro, in 4 months.'
#  'Mastering Generative AI for Strategic Advantage. Empower your leadership suite with the transformative potential of Generative AI'
#  'Advance your career in data engineering'
#  'Launch Your Career in Games. Learn to create worlds that captivate and inspire while building in-demand skills with the foundations for game design with Unreal Engine. No prior experience required'
#  'IBM AI Foundations for Business Specialization'
#  'Break into NLP. Master cutting-edge NLP techniques through four hands-on courses! Updated with TensorFlow labs in December 2023.'
#  'Develop key power skills to boost your work life. Master powerful people and soft skills for achieving professional success.'
#  'Innovate in your classroom and school. Master techniques for using ChatGPT to enhance rather than harm education'
#  'Master the Concepts of Reinforcement Learning. Implement a complete RL solution and understand how to apply AI tools to solve real-world problems.'
#  'Get on the fast track to a career in Data Analytics. In this certificate program, you’ll learn in-demand skills, and get AI training from Google experts. Learn at your own pace, no degree or experience required.'
#  'Renew your CBRS Professional Installer certification'
#  'Get Ahead with Key Business Technologies. Gain Foundational Understanding of Key Technologies Driving Modern Businesses'
#  'This course is part of Google Cybersecurity Professional Certificate'
#  'Unlock your potential in SAP Consulting. Build the core skills SAP Partners and customers are searching for across the world, and kick-start an exciting SAP career.'
#  'Instructional Design Foundations and Applications'
#  'Introduction to Engineering Mechanics'
#  'Artificial Intelligence in Marketing'
#  'Launch your career as a Junior Software Developer. Build job-ready skills for an in-demand career in software development in as little as 4 months. No prior experience or degree required to get started.'
#  'This course is part of Machine Learning Specialization'
#  'Learn about ESG Factors When Investing. Analyze the importance of ESG investing. Identify how the ESG approach should be an essential piece of your strategy based on various factors impacting and driving value.'
#  'Launch your career as an AI Product Manager. Build in-demand product management and generative AI skills to get job ready in 3 months or less.'
#  'Become an Excellent Public Speaker. Master techniques for designing and delivering clear and compelling presentations.'
#  'Launch your career as a back-end developer. Build job-ready skills for an in-demand career and earn a credential from Meta. No degree or prior experience required to get started.'
#  'Building AI Applications on AWS Cloud. Learn AI fundamentals and AWS services to develop practical applications to enhance productivity'
#  'Strategic Insights for Leaders on Agentic AI. Gain the knowledge to lead AI innovation in your organization by understanding Agentic AI and AI Agents.'
#  'Advance your career in health care management. Develop business skills and understand the American health care system to improve cost and quality.'
#  'Master Algorithmic Programming Techniques. Advance your Software Engineering or Data Science Career by Learning Algorithms through Programming and Puzzle Solving. Ace coding interviews by implementing each algorithmic challenge in this Specialization. Apply the newly-learned algorithmic techniques to real-life problems, such as analyzing a huge social network or sequencing a genome of a deadly pathogen.'
#  'Make Data-Driven Business Decisions. Achieve fluency in business data strategies in four discipline-specific courses.'
#  'Construction Project Management and Planning. Develop and understand the foundations of project planning and scheduling techniques'
#  'Prepare for a career in machine learning. Gain the in-demand skills and hands-on experience to get job-ready in less than 3 months.'
#  'Launch your career in Cloud Security. This self-paced Specialization gives a broad study of security controls, best practices, and techniques on Google Cloud.'
#  'Develop a Robust Foundation in Data Analytics. Build a job-ready data analytics skillset using industry-standard tools, including generative AI, to extract insights, make decisions, and solve real-world business problems.'
#  'Introduction to Systematic Review and Meta-Analysis'
#  'Positive Psychology: Well-being for life. Master strategies and tools that enable individuals and organizations to thrive'
#  'Become a Prompt Engineering Expert. Master prompt engineering patterns, techniques, and approaches to effectively leverage Generative AI'
#  'Get job-ready to launch your cybersecurity career. Build the information security skills and hands-on experience employers look for in less than 4 months. No prior experience required.'
#  'Discover your JavaScript developer potential. Solidify your cloud application developer skills with essential JavaScript technologies and NoSQL databases'
#  'Boost Your Productivity with AI Tools. New to AI? Learn from Google experts how AI can help you speed up daily tasks and spark new ideas.'
#  'Become a Machine Learning expert. Master the fundamentals of deep learning and break into AI. Recently updated with cutting-edge techniques!'
#  'Advance your cloud career in database engineering'
#  'Generative AI Mastery: Automate with ChatGPT. Learn to perform complex tasks effortlessly using the power of generative AI'
#  'Learn to Program and Analyze Data with Python. Develop programs to gather, clean, analyze, and visualize data.'
#  'Become fluent in the rules of the new economy. Learn how to use intellectual property law to protect and maximize the value of your innovations'
#  'Become a Fluent Python Programmer. Learn the fundamentals and become an independent programmer.'
#  'Learn cosmetic science from Olay scientists. Build a foundational understanding about the industry processes of creating safe and effective cosmetic formulas for skincare, haircare, hygiene cosmetics, color cosmetics, cleansing, and fragrances.'
#  'Explore the Scope of Dentistry and Oral Health. After completing this specialization, the learner will be able to recognize the scope of dental therapy and identify the relationship between oral and systemic health.'
#  'Fast-track your deep learning engineering career. Build the deep learning expertise employers are looking for in just 3 months'
#  'AWS Fundamentals Specialization'
#  'Prepare for a Career in AI & ML Engineering. Build, deploy, and innovate with advanced techniques and real-world projects. Intermediate programming knowledge of Python required.'
#  'Pursue your passion and improve your productivity. Learn how to use the best-in-class suite of apps that help you stay connected and get things done.'
#  'Enterprise AI Automation With Java AI Agents. Learn to build powerful AI agents and AI agent architectures in Java that work with nearly any API.'
#  'Build real-world AI with RAG and agentic AI. Use AI tools to streamline automation, drive innovation & take your career further, faster.'
#  'Master Mental Health Theories and Development. Gain a thorough understanding of mental health through professional standards, theoretical frameworks, and comprehensive insights into developmental stages, difficulties, and disorders.'
#  'Learn to execute successful M&A strategies. Learners will be able to gain a wholistic understanding of how successful M&A deals are structured and executed to create value for the organization'
#  'Elevate your Product Manager career with Gen AI. Build in-demand hands-on generative AI skills to boost your Product Manager career in under 2 months. No experience needed to get started'
#  'Learn and Master Full-Stack Web Development. Master both front-end and back-end skills to build web apps end-to-end'
#  'Get on the fast track to a career in digital marketing. In this certificate program, you’ll learn in-demand skills, and get AI training from Google experts. Learn at your own pace, no degree or experience required.'
#  'Launch your career as a cybersecurity professional. Build job-ready skills and prep for the CompTIA Security+ exam with this program.'
#  'Get on the fast track to a career in UX design. In this certificate program, you’ll learn in-demand skills, and get AI training from Google experts. Learn at your own pace, no degree or experience required.'
#  'Learn the Fundamentals of AI and Machine Learning. Develop a deployment strategy for incorporating AI, ML, and Big Data into your organization that will take advantage of cutting-edge technologies'
#  'Launch your career in Business Intelligence. Gain the in-demand skills and hands-on experience to get job-ready in less than 4 months. No prior experience required.'
#  'Launch your generative AI Data Engineering career. Get job-ready as a data engineer with knowledge of generative AI! No prior experience necessary'
#  'This course is part of Introduction to Generative AI Learning Path Specialization'
#  'Master CNA Skills with Healthcare Knowledge. Equip students with essential CNA skills, professional practices, and knowledge of anatomy.'
#  'Future-proof your Java career opportunities. Master GenAI & create AI Java apps in 2 months. No prior AI experience required.'
#  'Medical Neuroscience'
#  'Become an SEO Expert. Master search engine optimization tools and strategies'
#  'Launch your career as a Power BI analyst. Build job-ready skills for an in-demand career in as little as 3 months. No prior experience required to get started. This program can also prepare you for the Microsoft PL-300 Certification exam.'
#  'Make Smarter Business Decisions With Data Analysis. Understand data, apply data analytics tools and create effective business intelligence presentations'
#  'Get job-ready for your first role in BI. Build the in-demand skills you need to get started in business intelligence (BI) in just 2 months. No degree or prior experience required.'
#  'Primeros Auxilios Psicológicos (PAP)'
#  'Launch your Product Manager career with Microsoft. Learn in-demand market research skills and become a job-ready Product Manager in less than 3 months. No degree or experience required.'
#  'Build job-ready front-end skills employers need. Master the development skills to plan, build, deploy, and test web designs and application interfaces in just 4 months!'
#  'Unlock Potential of Gen AI for Customer Support. Learn how to leverage the capabilities and tools of generative AI to provide enhanced customer support and drive excellent customer experiences in just 3 weeks!'
#  'Getting started with Google Workspace Specialization'
#  'This course is part of Deep Learning Specialization'
#  'Become a CBRS Certified Professional Installer by Google'
#  'Get job-ready as an AI engineer. Build the AI engineering skills and practical experience you need to catch the eye of an employer in less than 4 months. Power up your resume!'
#  'Explore Art and Ideas of Our Time. Develop a deeper understanding of artists’ and designers’ processes, and gain confidence in looking at and talking about art.'
#  'ChatGPT-Powered Email Automation and Productivity. Master ChatGPT-driven workflows to automate email tasks, streamline communication, and organize important information effortlessly with Zapier.'
#  'Successful Negotiation: Essential Strategies and Skills'
#  'Power your Product Owner career with GenAI. Become proficient in GenAI tools in 3 weeks to optimize the product lifecycle and drive results.'
#  'Build Business and Financial Models. Use spreadsheet models to make data-driven financial decisions'
#  'Mathematics for Machine Learning. Learn about the prerequisite mathematics for applications in data science and machine learning'
#  'Launch your career in data analytics. Build job-ready skills – and must-have AI skills – for an in-demand career. Earn a credential from Meta in 5 months or less. No degree or prior experience required.'
#  'This course is part of Intuit Academy Bookkeeping Professional Certificate'
#  'Become a Power BI and Power Platform Expert. Boost Productivity, Automate Processes, and Gain Valuable Insights'
#  'Learn AI Agent Fundamentals from the Ground Up. Learn how to build resilient AI agents and develop Agentic AI skills in Python that will remain relevant despite the rapidly evolving AI landscape.'
#  'First Step Korean'
#  'Launch your career in marketing.. Build job-ready skills in digital marketing, content development, branding, and social media.'
#  'Turn Your Idea into a Funded Business. Develop, launch, fund and grow your own business'
#  'Finance & Quantitative Modeling for Analysts Specialization'
#  'Data Engineering on Google Cloud. Launch your career in Data Engineering. Deliver business value with big data and machine learning.'
#  'The AI Awakening: Implications for the Economy and Society'
#  'Kickstart a new IT and Cloud Career. Master hardware, operating systems, programming, database, networking, storage, cybersecurity, and Cloud computing essentials.'
#  'AI Infrastructure and Operations Fundamentals'
#  'Generative AI for Everyone' 'Introductory Human Physiology'
#  'Leadership and Business Skill for Immediate Impact. Apply practical strategies to becoming an effective organizational leader.'
#  'Launch Your Career in Personal Fitness Training. Master the knowledge and skills required to support clients in making lasting lifestyle changes.'
#  "Educator's Prompt Engineering. Elevate teaching with tailored generative AI prompting skills"
#  'Build Essential Skills for the Workplace. Improve your employability and advance in today’s dynamic workforce.'
#  'Master Personal Automation with ChatGPT and Zapier. Learn how to harness ChatGPT, AI tools, GPTs, and Zapier to automate tasks, enhance productivity, and effectively solve real-world challenges across various domains.'
#  'Foundational Pharmacy Technician Career Training. Start your pharmacy career by learning the essentials of dosages, prescriptions, anatomy, and the soft skills essential to any healthcare career.'
#  'Learn SQL Basics for Data Science Specialization'
#  'Be a next generation sequencing data scientist.. Master the tools and techniques at the forefront of the sequencing data revolution.'
#  'Drive to Value with Agile Methods. Master an adaptive approach to product development'
#  'Game Theory'
#  'Advance Your IT Career with Cybersecurity Skills. Gain Flexibility with Self-Paced Learning'
#  'Unlock the Potential of Generative AI in BI. Learn how you can use the capabilities and tools of generative AI to boost your career in business intelligence'
#  'Learn to create a culture of compliance. Master the strategies for building an effective compliance program to manage risk'
#  'ChatGPT-Powered Excel: Transform Data Into Insight. Master AI-driven Excel skills to automate tasks, uncover insights, and create impactful data visualizations.'
#  'This course is part of AI For Business Specialization'
#  'Prepare for a career as a systems analyst. Build in-demand skills & hands-on experience employers want. No prior experience or degree required'
#  'Leading the Modern Day Business Specialization'
#  "Law's Generative AI Edge. Harness Generative AI to transform legal research and practice"
#  'Launch your career as a Cloud Support Associate. Build job-ready skills for an in-demand career in information technology in as little as 6 months. No prior experience required to get started.'
#  'Financial Markets'
#  'This course is part of AI in Healthcare Specialization'
#  'Brand Management: Aligning Business, Brand and Behaviour'
#  'Break into a new career as a Product Manager. No prior experience necessary to quickly get job ready as a certified product manager'
#  'Business Analytics with Excel: Elementary to Advanced'
#  'Launch your graphic design career.. Learn design fundamentals to build job-ready skills using Adobe Photoshop, Illustrator, and Express'
#  'Prepare for a career as a product manager. Gain the in-demand skills and hands-on experience to get job ready in less than 3 months. No prior experience required.'
#  'Learn to build AI apps with Tensorflow. Build, train, and optimize deep neural networks and dive deep into Computer Vision, Natural Language Processing, and Time Series Analysis, along with best practices and hands-on experience in one of the most in-demand deep learning frameworks.'
#  'Launch Your Career in Data Science. A ten-course introduction to data science, developed and taught by leading professors.'
#  'Launch your career in Cybersecurity. Acquire the knowledge you need to work in Cybersecurity'
#  'Get ahead with key business and technical skills. Understand how current technologies are changing industry and create strategy to transform your business'
#  'Fintech: Foundations & Applications of Financial Technology Specialization'
#  'Improve Your Career With Advanced Six Sigma. Dive deeper into proven principles and tools to improve quality assurance in your organization'
#  'Launch your career as a cybersecurity analyst. Build job-ready skills – and must-have AI skills – for an in-demand career. Earn a credential from Microsoft. No prior experience required.'
#  'Understanding Procedures and Administration. Medical Office Procedures and Administration Fundamentals provides students with a comprehensive overview of key administrative functions in healthcare settings, including patient scheduling, medical billing, office management, and essential regulatory compliance – equipping them with the foundational skills needed to excel in medical office administration.'
#  'Learn To Think Like A Computer Scientist. Master the fundamentals of the design and analysis of algorithms.'
#  'Master Project Management with ChatGPT. Learn how to leverage ChatGPT and AI to streamline project planning, execution, and optimization, transforming how you manage and deliver successful projects.'
#  'Kickstart your Career in BI Engineering. Develop job-ready skills for an entry level role in Data Warehousing.'
#  'Launch your career as a Database Engineer. Build job-ready skills for an in-demand career and earn a credential from Meta. No degree or experience required to get started.'
#  'Advance your career to high demand field of DevOps. Build on your software development skills with the latest DevOps concepts, tools, and technologies to get job ready in less than 3 months.'
#  'Get job-ready as a mobile app developer. Build iOS and Android mobile app development skills and practical experience employers look for in just 6 months. No programming experience needed.'
#  'Launch your career in cloud computing. Build job-ready skills and gain credentials to go from beginner to job-ready in 4 months or less. No degree or prior experience required.'
#  'Generative AI for You. Build and train personalized assistants with Generative AI'
#  'Understanding Finance and Financial Markets. Learners will gain comprehensive knowledge and skills in financial markets, corporate finance, accounting, investment strategies, risk management, and ESG principles.'
#  'Introduction to Electronics'
#  'Prepare for a career as a full stack developer. Build job-ready skills – and must-have AI skills – for an in-demand career. Earn a credential from IBM.'
#  'Private Equity and Venture Capital'
#  'Fast-track your career with job-ready GenAI skills. Master GenAI-powered mobile app development and build the practical experience employers are looking for in just 3 months.'
#  'AI for Medicine Specialization'
#  'Understanding the Brain: The Neurobiology of Everyday Life'
#  'Launch your career as a project manager. Build job-ready skills and prepare for the Project Management Professional (PMP) certification exam. No prior experience required.'
#  'Introduction to Negotiation: A Strategic Playbook for Becoming a Principled and Persuasive Negotiator'
#  'Prepare for a career in data analytics. Gain the in-demand skills and hands-on experience to get job-ready in less than 3 months. No prior experience required.'
#  "Get on the fast track to a career in cybersecurity. In this certificate program, you'll learn in-demand skills, and get AI training from Google experts. Learn at your own pace, no degree or experience required."
#  'Launch your Career in Full-Stack Development. Start your journey as a full-stack developer. Develop job-ready AI-powered skills and earn a certificate from Microsoft. No experience required.'
#  'Learn the basics of finance and accounting. Build a foundation of core business skills in finance and accounting'
#  'This course is part of Python for Everybody Specialization'
#  'Gain the Medical Billing and Coding Fundamentals. Prepare for a career in the Medical Billing industry by gaining an understanding of the language of insurance, revenue cycles, and more.'
#  'Launch your career in Cloud Data Analytics. Build in-demand skills and gain credentials to go from beginner to job-ready in 10 weeks or less. No degree or prior experience required.'
#  'Stanford Introduction to Food and Health'
#  'Leading Effectively. Learn proven management techniques in just four courses.'
#  'Launch your career as a front-end developer. Build job-ready skills for an in-demand career and earn a credential from Meta. No degree or prior experience required to get started.'
#  'Prepare for a career as a back-end developer. Gain the in-demand skills and hands-on experience to get job-ready in less than 6 months.'
#  'Launch your career as an IT project manager. Get job-ready and prep for the Certified Associate in Project Management (CAPM) certification exam.'
#  'Drive Customer Behavior Online. A six-course overview of the latest digital marketing skills, taught by industry experts.'
#  'Introduction to Statistics'
#  'Unlock AI’s Potential with Effective Prompts. Learn from Google experts how to use AI effectively by writing clear and specific prompts.'
#  'Reinvent teaching with gen AI-powered innovation. Learn how to leverage gen AI tools to transform education and training and drive excellent learning experiences in just a few weeks!'
#  'Developer Best Practices on Google Cloud'
#  'Learn in-demand skills like data modeling, data visualization, and dashboarding and reporting in less than 2 months.'
#  'Launch your career as an IT support specialist. Build job-ready skills – and must-have AI skills – for an in-demand career. Earn a credential from Microsoft. No prior experience required.'
#  'Unlock Academic & Career Success with Data Science. Build the foundational knowledge and hands-on skills you need to forge new career opportunities, with no technical experience required.'
#  'Launch your career as a data architect. Learn in-demand skills like data engineering, database management, and data architecture in less than 5 months.'
#  'Learn machine learning with Google Cloud. Real-world experimentation with end-to-end ML'
#  'Learn machine learning through real use cases. Build the skills for a career in one of the most relevant fields of modern AI through hands-on projects and curriculum from IBM’s experts.'
#  'Build the foundation of your career in Software. Develop hands-on experience with Git, GitHub, Linux, and Python, and learn the fundamentals of Software Engineering.'
#  'Gain foundational literacy in cloud & digital transformation. Increase your cloud confidence so you can speak with colleagues in technical cloud roles and contribute to informed cloud-related business decisions.'
#  'Become a Generative AI Data Analyst. Learn how to use ChatGPT and generative AI tools to analyze data, automate workflows, and communicate insights with clarity and impact.'
#  'Boost Your Computer Programming Skills. With minimal previous exposure, learn two popular programming languages at an accelerated pace.'
#  'Use generative AI features in Google Workspace. Learn how to use generative AI with Gemini for Google Workspace to improve your productivity and efficiency'
#  'Launch your career in data science. Gain foundational data science skills to prepare for a career or further advanced learning in data science.'
#  'This course is part of Business Foundations Specialization'
#  'Unlock and leverage the potential of generative AI. Learn how you can use the capabilities of generative AI to enhance your work and daily life.'
#  'Launch your Career in Back-End Development. Start your journey as a back-end developer. Develop job-ready AI-powered skills and earn a certificate from Microsoft. No prior experience is required.'
#  'Start your career in the cloud.'
#  'Prepare for a career as a Java developer. Gain the in-demand skills and hands-on experience to get job-ready in 3 months. No prior experience required.'
#  'AI & Law'
#  'Implement a modern approach to product management. Master the fundamentals that create great teams and products'
#  'Develop Excel Skills from Microsoft. Develop your data analysis skills in Excel with AI-driven Copilot, hands-on projects, and expert guidance to accelerate your career.'
#  'Workday in Action Series'
#  'Build generative AI skills for data analytics. Enhance your career as a data analyst with knowledge of generative AI! No prior experience necessary.'
#  'Launch your Back-End JavaScript Developer career. Build the skills and hands-on experience to get job-ready in under four months. No degree or prior experience required.'
#  'Power up your business analysis career with GenAI. Build the game-changing GenAI skills businesses need in 3 weeks. No AI experience required.'
#  'Enhance your career in Cybersecurity with AI. Build in-demand generative AI skills and gain credentials for your cybersecurity career in 3 months or less. No degree or prior experience required.'
#  'AI-Driven Database Design For Professionals. Master SQL database design, query generation, and data visualization using AI.'
#  'Influencing: Storytelling, Change Management and Governance Specialization'
#  'Supply Chain Management. Master the Fundamentals: Logistics, Operations, Planning, Sourcing, and Strategy'
#  'Solve Real Business Problems. Build a foundation of core business skills in marketing, finance, accounting and operations.'
#  'Introduction to Generative AI Learning Path Specialization'
#  'Start here to become an AWS Solutions Architect. Gain the skills and knowledge to design architectural solutions on AWS and prepare for your AWS Certified Solutions Architect - Associate exam.'
#  'Boost Your Career with New Business Knowledge. Master Business Management Fundamentals'
#  'Understand nature like a biologist.. Embark on a journey from the classroom to museums and nature reserves to gain a broad overview and appreciation of three important fields of biology.'
#  'Launch your DevOps and Software Engineering Career. Master DevOps, Agile, Scrum, CI/CD and Cloud Native with hands-on job-ready skills.'
#  'The launchpad to a career in IT. This program is designed to take beginner learners to job readiness in about three-to-six months.'
#  'Get hands-on skills for a career in data science. Learn Python, analyze and visualize data. Apply your skills to data science and machine learning.'
#  'Master AI to Transform HR Operations. Master AI patterns to streamline hiring, development, and communications.'
#  'Advance Your IT Career with Cybersecurity Skills. Gain Flexibility with Self-Paced Learning.'
#  'Machine Learning in Production'
#  'Generative AI with Large Language Models'
#  'TESOL Certificate, Part 1: Teach English Now!. Learn theory and the practical strategies of English as a Second Language teaching.'
#  'Master Microsoft Office and Power Platform. Boost your productivity and become an Expert in Word, Excel, PowerPoint, and Power Platform'
#  'Learn essential skills in cancer biology, cancer metastasis, and prostate cancer, that will enable you to develop a deeper understanding of the impact of cancer on the human body.'
#  'Workday Basics Series'
#  'Advance your career as a Cloud Security Engineer'
#  'Data Science: Foundations using R Specialization'
#  'Launch Your Career in Marketing Analytics. Build job-ready skills – and must-have AI skills – for an in-demand career. Earn a credential from Meta in 7 months or less. No degree or prior experience required.'
#  'Leap ahead in data science using generative AI. Build in-demand hands-on generative AI skills to supercharge your data science career in under 1 month'
#  'Unlock Potential of Gen AI in Digital Marketing. Learn how to leverage the capabilities & tools of genAI to create effective marketing content'
#  'English for Career Development'
#  'GCP Principles for Ethical Clinical Trials'
#  'Enhance Your Skills in Risk Management. Understand the theory and practice of risk management and the expected results from a successful risk management process.'
#  'Introduction to Finance: The Basics'
#  'Get on the fast track to a career in project management. In this certificate program, you’ll learn in-demand skills, and get AI training from Google experts. Learn at your own pace, no degree or experience required.'
#  'Build smarter apps with RAG and GenAI Tools. Get hands-on building GenAI-powered apps using RAG, vector databases, & advanced retrieval tools.'
#  'Launch Your Career as an English Teacher. Master strategies to teach English as a second or foreign language.'
#  'Unlock your potential with AI. Build job-ready AI skills to enhance your career. Everyone welcome. No prior AI background required.'
#  'Become a cross-platform mobile app developer. Learn in-demand skills for developing reliable, scalable and user-friendly mobile apps for multiple operating systems, such as iOS and Android.'
#  'Build job-ready database skills. Gain practical experience in the high-demand fields of data management and data engineering, valued by employers with hands-on skills and experience employers look for.'
#  'Launch your career as an Android app developer. Build job-ready skills for an in-demand career and earn a credential from Meta. No degree or prior experience required to get started.'
#  'Master fundamental web development skills. Build frontend and backend skills in web development to start your journey as a web developer'
#  'This course is part of Mathematics for Machine Learning and Data Science Specialization'
#  'Unlock the Potential of Generative AI in HR. Learn how you can use the capabilities and tools of generative AI to enhance your career in human resources (HR)'
#  'Prepare for a career as an IT project manager. Build job-ready skills and prepare for the CAPM certification exam. No prior experience required.'
#  'Global Diplomacy – Diplomacy in the Modern World'
#  'Unlock your cybersecurity professional potential. Develop fluency in essential Cybersecurity skills and competencies and safeguard your digital assets.'
#  'Master the Toolkit of AI and Machine Learning. Mathematics for Machine Learning and Data Science is a beginner-friendly Specialization where you’ll learn the fundamental mathematics toolkit of machine learning: calculus, linear algebra, statistics, and probability.'
#  'Get job-ready as a Business Analyst. Build the essential skills, technical expertise, and hands-on experience with key business analysis tools'
#  'Launch your career as a content creator.. Build in-demand skills in visual design, social media , and multimedia storytelling.'
#  'Learn in-demand skills like Python, Git, and IT automation to advance your career'
#  'Advance your ML career with Gen AI and LLMs. Master the essentials of Gen AI engineering and large language models (LLMs) in just 3 months.'
#  'Supercharge your program management with GenAI. Master GenAI tools and techniques to enhance your program management capabilities and outcomes.']

# %% [markdown]
# ## Clean and normalize text

# %% [markdown]
# ### 1️⃣ Normalize duration into hours

# %%
duration_counts = df['Duration'].value_counts()
display(duration_counts)
# Out:
# Duration
# Flexible schedule       121
# 1 month                 102
# 2 months                 43
# 3 months                 35
# 4 months                 20
# 6 months                  7
# 5 months                  6
# 8 months                  3
# 7 hours to complete       2
# 9 hours to complete       2
# 3 hours to complete       2
# 14 hours to complete      2
# 7 months                  2
# 18 hours to complete      2
# 12 hours to complete      2
# 2 hours to complete       1
# 13 hours to complete      1
# 20 hours to complete      1
# 6 hours to complete       1
# 45 hours to complete      1
# 33 hours to complete      1
# 9 months                  1
# 10 hours to complete      1
# 40 hours to complete      1
# Name: count, dtype: int64

# %%
def normalize_duration(duration_str):
    if pd.isna(duration_str):
        return np.nan
    duration_str = duration_str.lower().strip()

    if 'hours to complete' in duration_str:
        return int(duration_str.split()[0])
    elif 'month' in duration_str:
        months = int(duration_str.split()[0])
        # assuming 10 hours per week, and 4 week per month
        return months * 40
    elif 'flexible' in duration_str:
        return np.nan  # temporarily NaN, to be replaced later

df['Duration'] = df['Duration'].apply(normalize_duration)

#replace nan with median
median_duration = df['Duration'].median()
df['Duration'] = df['Duration'].fillna(median_duration)
df.rename(columns={'Duration': 'Duration (in hour)'}, inplace=True)
df
# Out:
#                                                  Title  \
# 0    Microsoft Business Analyst Professional Certif...
# 1          Data Engineering Foundations Specialization
# 2                              Psychological First Aid
# 3    Tableau Business Intelligence Analyst Professi...
# 4                      Think like a CFO Specialization
# ..                                                 ...
# 355      IBM Business Analyst Professional Certificate
# 356     Adobe Content Creator Professional Certificate
# 357  Google IT Automation with Python Professional ...
# 358  Generative AI Engineering with LLMs Specializa...
# 359  Generative AI for Program Managers Specialization
#
#                       Partner                    Subject  \
# 0                   Microsoft          Business Strategy
# 1                         IBM            Data Management
# 2    Johns Hopkins University                 Psychology
# 3    Tableau Learning Partner              Data Analysis
# 4        IESE Business School                    Finance
# ..                        ...                        ...
# 355                       IBM        Business Essentials
# 356                     Adobe                  Marketing
# 357                    Google     Support and Operations
# 358                       IBM           Machine Learning
# 359                       IBM  Leadership and Management
#
#                                            Description  Rating  \
# 0    Launch your career as a business analyst. Buil...     4.6
# 1    Build the Foundation for a Data Engineering Ca...     4.7
# 2                              Psychological First Aid     4.8
# 3    Launch your career in Data Analytics. Build in...     4.7
# 4                      Think like a CFO Specialization     4.8
# ..                                                 ...     ...
# 355  Get job-ready as a Business Analyst. Build the...     4.8
# 356  Launch your career as a content creator.. Buil...     4.7
# 357  Learn in-demand skills like Python, Git, and I...     4.8
# 358  Advance your ML career with Gen AI and LLMs. M...     4.5
# 359  Supercharge your program management with GenAI...     4.8
#
#                   Level  Duration (in hour)  \
# 0        Beginner level               120.0
# 1        Beginner level                80.0
# 2        Beginner level                 6.0
# 3        Beginner level               320.0
# 4        Beginner level                40.0
# ..                  ...                 ...
# 355      Beginner level               120.0
# 356      Beginner level               160.0
# 357      Advanced level               240.0
# 358  Intermediate level               120.0
# 359  Intermediate level                40.0
#
#                                                 Skills  \
# 0    ['Business Process Modeling', 'Pivot Tables An...
# 1    ['Database Design', 'Database Management Syste...
# 2    ['Trauma Care', 'Crisis Intervention', 'Triage...
# 3    ['Spatial Data Analysis', 'Data Visualization ...
# 4    ['Balance Sheet', 'Working Capital', 'Capital ...
# ..                                                 ...
# 355  ['Stakeholder Engagement', 'Business Analytics...
# 356  ['Storytelling', 'Content Marketing', 'Social ...
# 357  ['Unit Testing', 'Programming Principles', 'Gi...
# 358  ['Text Mining', 'Large Language Modeling', 'Ap...
# 359  ['Project Management', 'Large Language Modelin...
#
#                                                    URL
# 0    https://www.coursera.org/professional-certific...
# 1    https://www.coursera.org/specializations/data-...
# 2    https://www.coursera.org/learn/psychological-f...
# 3    https://www.coursera.org/professional-certific...
# 4    https://www.coursera.org/specializations/think...
# ..                                                 ...
# 355  https://www.coursera.org/professional-certific...
# 356  https://www.coursera.org/professional-certific...
# 357  https://www.coursera.org/professional-certific...
# 358  https://www.coursera.org/specializations/gener...
# 359  https://www.coursera.org/specializations/gener...
#
# [360 rows x 9 columns]

# %% [markdown]
# ### 2️⃣ Convert string into list on column skills

# %%
df['Skills'] = df['Skills'].apply(ast.literal_eval)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               360 non-null    object
#  1   Partner             360 non-null    object
#  2   Subject             360 non-null    object
#  3   Description         360 non-null    object
#  4   Rating              360 non-null    float64
#  5   Level               360 non-null    object
#  6   Duration (in hour)  360 non-null    float64
#  7   Skills              360 non-null    object
#  8   URL                 360 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 25.4+ KB

# %% [markdown]
# ### 3️⃣ Clean description column

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Dwi Wahyu
# [nltk_data]     Lestari\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Dwi Wahyu
# [nltk_data]     Lestari\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# %%
def clean_and_lemmatize(text):
    text = text.lower()

    # remove numbers and special characters
    text = re.sub(r'[^a-z\s]', '', text)
    words = text.split()

    # remove stopwords
    words = [w for w in words if w not in stop_words]

    # lemmatize
    words = [lemmatizer.lemmatize(w) for w in words]
    return ' '.join(words)

# %%
df['Skills'] = df['Skills'].apply(lambda x: ' '.join(x) if isinstance(x, list) else '')

# %%
df['Title'] = df['Title'].apply(clean_and_lemmatize)
df['Description'] = df['Description'].apply(clean_and_lemmatize)
df['Skills'] = df['Skills'].apply(clean_and_lemmatize)
df
# Out:
#                                                  Title  \
# 0    microsoft business analyst professional certif...
# 1           data engineering foundation specialization
# 2                              psychological first aid
# 3    tableau business intelligence analyst professi...
# 4                        think like cfo specialization
# ..                                                 ...
# 355      ibm business analyst professional certificate
# 356     adobe content creator professional certificate
# 357  google automation python professional certificate
# 358       generative ai engineering llm specialization
# 359       generative ai program manager specialization
#
#                       Partner                    Subject  \
# 0                   Microsoft          Business Strategy
# 1                         IBM            Data Management
# 2    Johns Hopkins University                 Psychology
# 3    Tableau Learning Partner              Data Analysis
# 4        IESE Business School                    Finance
# ..                        ...                        ...
# 355                       IBM        Business Essentials
# 356                     Adobe                  Marketing
# 357                    Google     Support and Operations
# 358                       IBM           Machine Learning
# 359                       IBM  Leadership and Management
#
#                                            Description  Rating  \
# 0    launch career business analyst build jobready ...     4.6
# 1    build foundation data engineering career devel...     4.7
# 2                              psychological first aid     4.8
# 3    launch career data analytics build indemand sk...     4.7
# 4                        think like cfo specialization     4.8
# ..                                                 ...     ...
# 355  get jobready business analyst build essential ...     4.8
# 356  launch career content creator build indemand s...     4.7
# 357  learn indemand skill like python git automatio...     4.8
# 358  advance ml career gen ai llm master essential ...     4.5
# 359  supercharge program management genai master ge...     4.8
#
#                   Level  Duration (in hour)  \
# 0        Beginner level               120.0
# 1        Beginner level                80.0
# 2        Beginner level                 6.0
# 3        Beginner level               320.0
# 4        Beginner level                40.0
# ..                  ...                 ...
# 355      Beginner level               120.0
# 356      Beginner level               160.0
# 357      Advanced level               240.0
# 358  Intermediate level               120.0
# 359  Intermediate level                40.0
#
#                                                 Skills  \
# 0    business process modeling pivot table chart bu...
# 1    database design database management system big...
# 2    trauma care crisis intervention triage stress ...
# 3    spatial data analysis data visualization softw...
# 4    balance sheet working capital capital budgetin...
# ..                                                 ...
# 355  stakeholder engagement business analytics busi...
# 356  storytelling content marketing social medium i...
# 357  unit testing programming principle github inte...
# 358  text mining large language modeling applied ma...
# 359  project management large language modeling cha...
#
#                                                    URL
# 0    https://www.coursera.org/professional-certific...
# 1    https://www.coursera.org/specializations/data-...
# 2    https://www.coursera.org/learn/psychological-f...
# 3    https://www.coursera.org/professional-certific...
# 4    https://www.coursera.org/specializations/think...
# ..                                                 ...
# 355  https://www.coursera.org/professional-certific...
# 356  https://www.coursera.org/professional-certific...
# 357  https://www.coursera.org/professional-certific...
# 358  https://www.coursera.org/specializations/gener...
# 359  https://www.coursera.org/specializations/gener...
#
# [360 rows x 9 columns]

# %%
df.to_csv('data/coursera_course_details_preprocessed.csv', index=False)
